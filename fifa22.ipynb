# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\kelvi\\Documents\\Big data analaytics\\SEM 2\\Big data Algorithm and statistics(2053)\\project\\Main csv.csv')
df.head(50)
df.head(20)
# df.describe()
# df
# Out:
#     sofifa_id         short_name  year player_positions  overall  potential  \
# 0      158023           L. Messi  2022       RW, ST, CF       93         93
# 1      188545     R. Lewandowski  2022               ST       92         92
# 2       20801  Cristiano Ronaldo  2022           ST, LW       91         91
# 3      190871          Neymar Jr  2022          LW, CAM       91         91
# 4      192985       K. De Bruyne  2022          CM, CAM       91         91
# 5      200389           J. Oblak  2022               GK       91         93
# 6      231747          K. Mbappé  2022           ST, LW       91         95
# 7      167495           M. Neuer  2022               GK       90         90
# 8      192448      M. ter Stegen  2022               GK       90         92
# 9      202126            H. Kane  2022               ST       90         90
# 10     215914           N. Kanté  2022          CDM, CM       90         90
# ...

# %%
df.isna().any()
# Out:
# sofifa_id                      False
# short_name                     False
# year                           False
# player_positions               False
# overall                        False
# potential                      False
# value_eur                       True
# wage_eur                        True
# age                            False
# height_cm                      False
# weight_kg                      False
# club_name                       True
# league_name                     True
# league_level                    True
# club_position                   True
# nationality_name               False
# preferred_foot                 False
# weak_foot                      False
# skill_moves                    False
# pace                           False
# shooting                       False
# passing                        False
# dribbling                      False
# defending                      False
# physic                         False
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [sofifa_id, short_name, year, player_positions, overall, potential, value_eur, wage_eur, age, height_cm, weight_kg, club_name, league_name, league_level, club_position, nationality_name, preferred_foot, weak_foot, skill_moves, pace, shooting, passing, dribbling, defending, physic, attacking_crossing]
# Index: []
#
# [0 rows x 26 columns]

# %%
# dropping null values for colums of value_eur and wage_eur since its irrelevent
df.dropna(subset=['value_eur','wage_eur'],inplace=True)

# %%
df.isna().any()
# Out:
# sofifa_id                      False
# short_name                     False
# year                           False
# player_positions               False
# overall                        False
# potential                      False
# value_eur                      False
# wage_eur                       False
# age                            False
# height_cm                      False
# weight_kg                      False
# club_name                      False
# league_name                    False
# league_level                   False
# club_position                  False
# nationality_name               False
# preferred_foot                 False
# weak_foot                      False
# skill_moves                    False
# pace                           False
# shooting                       False
# passing                        False
# dribbling                      False
# defending                      False
# physic                         False
# ...

# %%
# null_rows = df[df.isnull().any(axis=1)]
# null_rows

# %%
## replacing null with 0 for pace,shooting,drinbbling,defending,physic as it doesnt apply for gk
df.fillna({'pace':0,'shooting':0,'passing':0,'dribbling':0,'defending':0,'physic':0,'goalkeeping_speed':0}, inplace=True)

# %%
df.isna().any()
# Out:
# sofifa_id                      False
# short_name                     False
# year                           False
# player_positions               False
# overall                        False
# potential                      False
# value_eur                      False
# wage_eur                       False
# age                            False
# height_cm                      False
# weight_kg                      False
# club_name                      False
# league_name                    False
# league_level                   False
# club_position                  False
# nationality_name               False
# preferred_foot                 False
# weak_foot                      False
# skill_moves                    False
# pace                           False
# shooting                       False
# passing                        False
# dribbling                      False
# defending                      False
# physic                         False
# ...

# %%
print(df.columns)
# Out:
# Index(['sofifa_id', 'short_name', 'year', 'player_positions', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'age', 'height_cm', 'weight_kg',
#        'club_name', 'league_name', 'league_level', 'club_position',
#        'nationality_name', 'preferred_foot', 'weak_foot', 'skill_moves',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
# ...

# %%
## selccting the columns to anayse forwards
forw=df[df['club_position'].isin(['FW', 'ST', 'LW', 'RW'])]

fw=forw[['short_name','overall','potential','value_eur','wage_eur','age','height_cm','weight_kg','club_name','league_name','club_position','preferred_foot','weak_foot','skill_moves','pace','shooting','dribbling','attacking_finishing','attacking_heading_accuracy','attacking_volleys','skill_dribbling','skill_fk_accuracy','movement_sprint_speed']]
fw
# Out:
#               short_name  overall  potential    value_eur  wage_eur  age  \
# 0               L. Messi       93         93   78000000.0  320000.0   34
# 1         R. Lewandowski       92         92  119500000.0  270000.0   32
# 2      Cristiano Ronaldo       91         91   45000000.0  270000.0   36
# 3              Neymar Jr       91         91  129000000.0  270000.0   29
# 6              K. Mbappé       91         95  194000000.0  230000.0   22
# ...                  ...      ...        ...          ...       ...  ...
# 17516        D. Williams       56         65     325000.0     600.0   21
# 17824        Xu Tianyuan       55         60     190000.0    2000.0   24
# 18019     P. Mutswunguma       55         59     190000.0     500.0   21
# 18235          B. Scorza       54         68     250000.0     500.0   20
# 18337           Li Xiang       54         54     110000.0    3000.0   30
#
#        height_cm  weight_kg                club_name  \
# ...

# %%
mean_ov=fw['overall'].mean()
print('mean of the overall rating is ',meanov)
mode_ov=fw['overall'].mode()
print('mode of the overall rating is ',modeov)
max_ov=fw['overall'].max()
print(max_ov)
min_ov=fw['overall'].min()
print(min_ov)
std_ov=fw['overall'].std()
print('stand dev of the overall rating is',std_ov)


mean_age=fw['age'].mean()
print('mean of the age is ',meanage)
mode_age=fw['age'].mode()
print('mode of the age rating is ',modeage)
# Out:
# mean of the overall rating is  65.76018784242108
# mode of the overall rating is  0    65
# Name: overall, dtype: int64
# 93
# 54
# stand dev of the overall rating is 6.274743180018152
# mean of the age is  25.190033915992696
# mode of the age rating is  0    21
# Name: age, dtype: int64

# %%
## finding out the skewness


import matplotlib.pyplot as plt
plt.hist(fw['overall'], bins=20)
plt.xlabel('Player rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Here the skewness is 0.6 ,which indicate a  moderate degree of skewness towards the right .which means that no of players having less rayting is more than those having higher rating

# %%
# Calculate the skewness of player ratings
skewness = fw['overall'].skew()

print('the skewness of the player rating is ',skewness)
# Out:
# the skewness of the player rating is  0.6809931382561542

# %% [markdown]
# # finding out corelation

# %% [markdown]
# corelation b/w rating and pace

# %%
plt.scatter(fw['pace'], fw['overall'])

# Set the title and axis labels
plt.title('FIFA 22 Player Ratings vs. Speed')
plt.xlabel('Speed')
plt.ylabel('Overall Rating')

# Display the plot
plt.show()

# %%
# Calculating the correlation coefficient between speed and overall rating
correlation_coefficient = fw['pace'].corr(fw['overall'])

# Print the correlation coefficient
print('Correlation Coefficient:', correlation_coefficient)
# Out:
# Correlation Coefficient: 0.22387550026404224

# %% [markdown]
# A weak positve corelation between rating and pace

# %% [markdown]
# corelation b/w dribbling and overall rating

# %%
plt.scatter(fw['dribbling'], fw['overall'])

# Set the title and axis labels
plt.title('FIFA 22 Player Ratings vs dribbling')
plt.xlabel('dribbling')
plt.ylabel('Overall Rating')

# Display the plot
plt.show()

# %%
# Calculating the correlation coefficient between dribbling and overall rating
correlation_coefficient = fw['dribbling'].corr(fw['overall'])

# Print the correlation coefficient
print('Correlation Coefficient:', correlation_coefficient)
# Out:
# Correlation Coefficient: 0.8457027416774245

# %% [markdown]
# a strong positive corelation between dribbling and overall

# %% [markdown]
# corelation b/w shooting and overall rating

# %%
plt.scatter(fw['shooting'], fw['overall'])

# Set the title and axis labels
plt.title('FIFA 22 Player Ratings vs shooting')
plt.xlabel('shooting')
plt.ylabel('Overall Rating')

# Display the plot
plt.show()

# %%
# Calculating the correlation coefficient between shooting and overall rating
correlation_coefficient = fw['shooting'].corr(fw['overall'])

# Print the correlation coefficient
print('Correlation Coefficient:', correlation_coefficient)
# Out:
# Correlation Coefficient: 0.8521678796981416

# %% [markdown]
# A strong corelation between shooting and overall rating
